# %%
import pandas as pd
from nsepy import get_history
from datetime import date
import time


NotAvailable = pd.DataFrame()
# List of Stocks
NSE_stocks = pd.read_csv("/home/svdr/nsestocks/Universe/NSEstocks.csv")
NIFTY200_stocks = pd.read_csv("/home/svdr/nsestocks/Universe/NIFTY200.csv")
NIFTY200_stocks = NIFTY200_stocks["Symbol"]

#Update data:
for element in NIFTY200_stocks:
    try:
        #read existing file
        current_data = pd.read_pickle("/home/svdr/nsestocks/StocksRaw/"+element+".pickle")
        last_day = current_data.index.max()
        #extract
        if last_day!=date.today():
            data = get_history(symbol=element, start=last_day, end=date.today())
            current_data = current_data.append(data)
            #remove duplicates
            current_data = current_data.loc[~current_data.index.duplicated(keep='first')]
            #save
            current_data.to_pickle("/home/svdr/nsestocks/StocksRaw/"+element+".pickle")
            print(element," done")
        else: 
            print(element,"already up to date")
    except:
        try:
            data = get_history(symbol=element, start=date(2008,1,1), end=date.today())
            data["Symbol"]=element
            data.to_pickle("/home/svdr/nsestocks/StocksRaw/"+element+".pickle")
        except:
            print(element,"NOT AVAILABLE")
            linie = {"Company":element}
            NotAvailable = NotAvailable.append(linie, ignore_index=True)
    time.sleep(1)
print("ALL DONE")
# Out:
# ACC already up to date
# AUBANK already up to date
# ADANIPORTS already up to date
# ADANIPOWER already up to date
# ADANITRANS already up to date
# ABCAPITAL already up to date
# ABFRL already up to date
# AJANTPHARM already up to date
# ALKEM already up to date
# AMARAJABAT  done
# AMBUJACEM already up to date
# APOLLOHOSP already up to date
# APOLLOTYRE already up to date
# ASHOKLEY already up to date
# ASIANPAINT already up to date
# AUROPHARMA already up to date
# DMART already up to date
# AXISBANK already up to date
# BAJAJ-AUTO already up to date
# BAJFINANCE already up to date
# BAJAJFINSV already up to date
# BAJAJHLDNG already up to date
# BALKRISIND already up to date
# BANDHANBNK already up to date
# BANKBARODA already up to date
# BANKINDIA already up to date
# BATAINDIA already up to date
# BERGEPAINT already up to date
# BEL already up to date
# BHARATFORG already up to date
# BHEL already up to date
# BPCL already up to date
# BHARTIARTL already up to date
# INFRATEL already up to date
# BIOCON already up to date
# BBTC already up to date
# BOSCHLTD already up to date
# BRITANNIA already up to date
# CESC already up to date
# CADILAHC already up to date
# CANBK already up to date
# CASTROLIND already up to date
# CHOLAFIN already up to date
# CIPLA already up to date
# CUB already up to date
# COALINDIA already up to date
# COLPAL already up to date
# CONCOR already up to date
# COROMANDEL already up to date
# CROMPTON already up to date
# CUMMINSIND already up to date
# DLF already up to date
# DABUR already up to date
# DALBHARAT already up to date
# DIVISLAB already up to date
# DRREDDY already up to date
# EDELWEISS already up to date
# EICHERMOT already up to date
# EMAMILTD already up to date
# ENDURANCE already up to date
# ENGINERSIN already up to date
# ESCORTS already up to date
# EXIDEIND already up to date
# FEDERALBNK already up to date
# FORTIS already up to date
# FCONSUMER already up to date
# FRETAIL already up to date
# GAIL already up to date
# GMRINFRA already up to date
# GICRE already up to date
# GLENMARK already up to date
# GODREJAGRO already up to date
# GODREJCP already up to date
# GODREJIND already up to date
# GODREJPROP already up to date
# GRAPHITE already up to date
# GRASIM already up to date
# GSPL already up to date
# HEG already up to date
# HCLTECH already up to date
# HDFCAMC already up to date
# HDFCBANK already up to date
# HDFCLIFE already up to date
# HAVELLS already up to date
# HEROMOTOCO already up to date
# HEXAWARE already up to date
# HINDALCO already up to date
# HINDPETRO already up to date
# HINDUNILVR already up to date
# HINDZINC already up to date
# HUDCO already up to date
# HDFC already up to date
# ICICIBANK already up to date
# ICICIGI already up to date
# ICICIPRULI already up to date
# IDBI already up to date
# IDFCFIRSTB already up to date
# ITC already up to date
# IBULHSGFIN already up to date
# IBVENTURES already up to date
# INDIANB already up to date
# INDHOTEL already up to date
# IOC already up to date
# IGL already up to date
# INDUSINDBK already up to date
# NAUKRI already up to date
# INFY already up to date
# INDIGO already up to date
# IPCALAB already up to date
# JSWENERGY already up to date
# JSWSTEEL already up to date
# JINDALSTEL already up to date
# JUBLFOOD already up to date
# JUBILANT already up to date
# KOTAKBANK already up to date
# L&TFH already up to date
# LTTS already up to date
# LICHSGFIN already up to date
# LTI already up to date
# LT already up to date
# LUPIN already up to date
# MRF already up to date
# MGL already up to date
# M&MFIN already up to date
# M&M already up to date
# MANAPPURAM already up to date
# MRPL already up to date
# MARICO already up to date
# MARUTI already up to date
# MFSL already up to date
# MINDTREE already up to date
# MOTHERSUMI already up to date
# MPHASIS already up to date
# MUTHOOTFIN already up to date
# NATCOPHARM already up to date
# NBCC  done
# NHPC  done
# NMDC  done
# NTPC  done
# NATIONALUM  done
# NESTLEIND  done
# NAM-INDIA  done
# OBEROIRLTY  done
# ONGC  done
# OIL  done
# OFSS  done
# PIIND  done
# PNBHOUSING  done
# PAGEIND  done
# PETRONET  done
# PFIZER  done
# PIDILITIND  done
# PEL  done
# PFC  done
# POWERGRID  done
# PRESTIGE  done
# PGHH  done
# PNB  done
# QUESS  done
# RBLBANK  done
# RECLTD  done
# RAJESHEXPO  done
# RELIANCE  done
# SBILIFE  done
# SRF  done
# SHREECEM  done
# SRTRANSFIN  done
# SIEMENS  done
# SBIN  done
# SAIL  done
# STRTECH  done
# SUNPHARMA  done
# SUNTV  done
# SYNGENE  done
# TVSMOTOR  done
# TCS  done
# TATACONSUM  done
# TATAMTRDVR  done
# TATAMOTORS  done
# TATAPOWER  done
# TATASTEEL  done
# TECHM  done
# NIACL  done
# RAMCOCEM  done
# TITAN  done
# TORNTPHARM  done
# TORNTPOWER  done
# UPL  done
# ULTRACEMCO  done
# UNIONBANK  done
# UBL  done
# MCDOWELL-N  done
# VGUARD  done
# VARROC  done
# VBL  done
# VEDL  done
# IDEA  done
# VOLTAS  done
# WHIRLPOOL  done
# WIPRO  done
# ZEEL  done
# ALL DONE

# %%
data = get_history(symbol="ADANIPORTS", start=last_day, end=date.today())

# %%
data
# Out:
#                 Symbol Series  Prev Close   Open    High     Low   Last  \
# Date
# 2020-05-28  ADANIPORTS     EQ      326.65  329.5  334.15  327.45  331.5
# 2020-05-29  ADANIPORTS     EQ      331.80  330.0  330.00  322.05  327.0
#
#             Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2020-05-28  331.8  330.51   5655407  1.869142e+14   54908             2207155
# 2020-05-29  323.8  324.02  12299544  3.985358e+14   73080             8624540
#
#             %Deliverble
# Date
# 2020-05-28       0.3903
# 2020-05-29       0.7012
