# %%
import pandas as pd

# %%
close = pd.read_pickle("/home/svdr/nsestocks/Data/close.pickle")

# %%
returns=close.div(close.shift(1))-1

# %%
returns[returns<-0.5].dropna(axis=1,how="all")
# Out:
#             ADANIPORTS  AJANTPHARM  APOLLOHOSP  ASIANPAINT  AUROPHARMA  \
# Date
# 2008-01-01         NaN         NaN         NaN         NaN         NaN
# 2008-01-02         NaN         NaN         NaN         NaN         NaN
# 2008-01-03         NaN         NaN         NaN         NaN         NaN
# 2008-01-04         NaN         NaN         NaN         NaN         NaN
# 2008-01-07         NaN         NaN         NaN         NaN         NaN
# 2008-01-08         NaN         NaN         NaN         NaN         NaN
# 2008-01-09         NaN         NaN         NaN         NaN         NaN
# 2008-01-10         NaN         NaN         NaN         NaN         NaN
# 2008-01-11         NaN         NaN         NaN         NaN         NaN
# 2008-01-14         NaN         NaN         NaN         NaN         NaN
# 2008-01-15         NaN         NaN         NaN         NaN         NaN
# 2008-01-16         NaN         NaN         NaN         NaN         NaN
# ...

# %%
for element in close.columns:
    print(returns[element].plot())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# ...
