# %%
import pandas as pd

# %%
NIFTY200 = pd.read_csv("/home/svdr/nsestocks/Universe/NIFTY200.csv")

# %%
close = pd.read_pickle("/home/svdr/nsestocks/Data/close.pickle")

# %%
close
# Out:
#                 ACC  AUBANK  ADANIPORTS  ADANIPOWER  ADANITRANS  ABCAPITAL  \
# Date
# 2008-01-01  1028.35     NaN     1296.85         NaN         NaN        NaN
# 2008-01-02  1023.05     NaN     1307.45         NaN         NaN        NaN
# 2008-01-03  1006.95     NaN     1275.80         NaN         NaN        NaN
# 2008-01-04   999.65     NaN     1240.35         NaN         NaN        NaN
# 2008-01-07  1001.85     NaN     1227.25         NaN         NaN        NaN
# 2008-01-08   985.30     NaN     1204.80         NaN         NaN        NaN
# 2008-01-09   970.00     NaN     1180.25         NaN         NaN        NaN
# 2008-01-10   938.85     NaN     1121.55         NaN         NaN        NaN
# 2008-01-11   898.70     NaN     1085.85         NaN         NaN        NaN
# 2008-01-14   876.55     NaN     1035.15         NaN         NaN        NaN
# 2008-01-15   869.50     NaN     1049.55         NaN         NaN        NaN
# ...

# %%
close
# Out:
#                 ACC  AUBANK  ADANIPORTS  ADANIPOWER  ADANITRANS  ABCAPITAL  \
# Date
# 2008-01-01  1028.35     NaN     1296.85         NaN         NaN        NaN
# 2008-01-02  1023.05     NaN     1307.45         NaN         NaN        NaN
# 2008-01-03  1006.95     NaN     1275.80         NaN         NaN        NaN
# 2008-01-04   999.65     NaN     1240.35         NaN         NaN        NaN
# 2008-01-07  1001.85     NaN     1227.25         NaN         NaN        NaN
# 2008-01-08   985.30     NaN     1204.80         NaN         NaN        NaN
# 2008-01-09   970.00     NaN     1180.25         NaN         NaN        NaN
# 2008-01-10   938.85     NaN     1121.55         NaN         NaN        NaN
# 2008-01-11   898.70     NaN     1085.85         NaN         NaN        NaN
# 2008-01-14   876.55     NaN     1035.15         NaN         NaN        NaN
# 2008-01-15   869.50     NaN     1049.55         NaN         NaN        NaN
# ...

# %%
pd.read_pickle
